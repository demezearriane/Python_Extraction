# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_Lilas = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\\Residence des Lilas.csv", sep=";")# Residence des Lilas

# %%
df_Lilas.head()
# Out:
#    note                                             resume  \
# 0   8.0                               Agréable et reposant
# 1   8.0  Idéal pour retour se ressourcer après une miss...
# 2   9.0                                         Fabuleux
# 3   7.0                                             Bien
# 4   9.6                         Belle résidence à Yaoundé
#
#                                         commentaires
# 0   Absence de groupe électrogène pour faire face...
# 1   Endroit très calme et parfait pour travailler...
# 2   RAS.| Leux propre et convivial. Avec tout ce ...
# 3   a part l'emplacement tout était parfait| L' a...
# 4   La résidence ne dispose pas d'enseigne ou écr...

# %%
df_Lilas["note"].head()
# Out:
# 0    8.0
# 1    8.0
# 2    9.0
# 3    7.0
# 4    9.6
# Name: note, dtype: float64

# %%
df_DjeugAppart = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\\Djeug_Appart hotel.csv", sep=";")# Djeug_Appart hotel

# %%
df_DjeugAppart.head()
# Out:
#    note                                             resume  \
# 0   9.0  Excellent rapport qualité/prix. Hôtes bienveil...
# 1   7.0                                        Logistique
# 2   9.0  Excellent hotel et  très très  bon rapport qua...
# 3   8.0                                         Très bien
# 4   8.0                                         Très bien
#
#                                         commentaires
# 0   Les plaques ne fonctionnaient pas correctemen...
# 1   L emplacement, coupure d eau et d internet | ...
# 2   Je n'ai pas trouvé les lits très confortable ...
# 3   Problème électrique temporaire Peu de passage...
# 4   Parking toujours plein. Des voitures garées e...

# %%
df_DjeugAppart["note"].head()
# Out:
# 0    9.0
# 1    7.0
# 2    9.0
# 3    8.0
# 4    8.0
# Name: note, dtype: float64

# %%
df_MassouBG = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\\Residence Massou Bastos Golf.csv", sep=";")# Residence Massou Bastos Golf

# %%
df_MassouBG.head()
# Out:
#    note                                             resume  \
# 0   8.0                            Un séjour très agréable
# 1  10.0                                 Mon séjour de rêve
# 2   9.2                                         Fabuleux
# 3   7.5  Résidence de luxe rapport qualité prix parfaite!!
# 4   7.5  Le cadre,  la forêt ,la vue et la tranquillité...
#
#                                         commentaires
# 0   Le stationnement un peu compliqué à cause des...
# 1   Pas d'accessibilité au wifi c'était gênant| L...
# 2                                  L’enregistrement|
# 3   les voisins peuvent être bruyants il faut don...
# 4   Le cadre,  la forêt ,la vue et la tranquillit...

# %%
df_villaContemp = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\\Villa contemporaine.csv", sep=";")#Villa contemporaine

# %%
df_villaContemp.head()
# Out:
#    note          resume                                       commentaires
# 0  10.0   Exceptionnel                        Très bel appart , à refaire|
# 1   8.0         PARFAIT   l'installation d'une climatisation ne serait ...
# 2   8.8       Satisfait   Manque de serviettes de bain Manque de savon ...
# 3   9.6      Fabuleux     Connection Wi-Fi un peu lente| Villa au calme...
# 4  10.0   Exceptionnel    Établissement situé dans un environnement cal...

# %%
df_hotelcouRW = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\\Hotel la couronne RW.csv", sep=";")#Hotel la couronne RW

# %%
df_hotelcouRW.head()
# Out:
#    note                                             resume  \
# 0   7.0           Séjour reposant et bien dans l'ensemble.
# 1   9.0                                        Magnificent
# 2   9.0  Un excellent séjour, confortable et un accueil...
# 3   9.0                                                TOP
# 4   9.0  Séjour parfait dans un établissement très agré...
#
#                                         commentaires
# 0   Le type de toilette (WC trop d'eau et ça fait...
# 1   La qualité des chambres et du service, le per...
# 2   Excellent accueil, personnel très disponible....
# 3   L'application totale du 24h/7 a la réception ...
# 4   Le petit déjeuner pourrait être amélioré pour...

# %%
df_hotelJouvInter = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\hotel jouvence inter.csv", sep=";")#hotel jouvence inter

# %%
df_hotelJouvInter.head()
# Out:
#    note                                             resume  \
# 0   8.0                                         Très bien
# 1   7.1                                             Bien
# 2   7.0                                             Bien
# 3   7.0                                             Bien
# 4   9.0  Dans l ensemble c était magnifique je recomman...
#
#                                         commentaires
# 0   - Le restaurant doit améliorer la qualité des...
# 1   Le petit déjeuner est de type service à la ca...
# 2                            Emplacement | Confort |
# 3   Chambre bruyante le matin. Pas de cuisine apr...
# 4   Le manque d une bonne pression d eau| Personn...

# %%
df_Charlestine = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\charlestine.csv", sep=";")#villa charlestine

# %%
df_Charlestine.head()
# Out:
#    note                            resume  \
# 0   8.0              Agréable et reposant
# 1  10.0                     Exceptionnel
# 2   8.8  Un voyage simplement excellent !
# 3  10.0                     Exceptionnel
# 4   7.0                            Bien
#
#                                         commentaires
# 0   Pas de WiFi et pas d'images TV| Le jardin, la...
# 1                       Tous etais bien| Magnifique|
# 2   La localisation de la Villa est assez diffici...
# 3                                                NaN
# 4                                                NaN

# %%
df_Safyad = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Safyad.csv", sep=";")#Hotel Safyad

# %%
df_Safyad.head()
# Out:
#    note       resume                                       commentaires
# 0   8.0   Très bien    Il y a du bruit tard le soir et très tôt le m...
# 1   9.0   Fabuleux     L'hotel est propre , personnel accueillant , ...
# 2   7.0         Bien   Les bruits venant du carrefour avoisinant. Am...
# 3   7.0       Bien            Pas pour le moment.| Pas pour le moment.|
# 4   7.5       Bien     C'est hôtel est confortable. Mais l'hôtel org...

# %%
df_jardTrop = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\jardin tropical.csv", sep=";")#jardin tropical

# %%
df_jardTrop.head()
# Out:
#    note                                             resume  \
# 0   7.0  j'aimerais bien y revenir mais il est très com...
# 1   9.0                                         Fabuleux
# 2   7.0                                             Bien
# 3   8.3                                         Très bien
# 4   7.9                                    Belle résidence
#
#                                         commentaires
# 0   l'accès au site très pénible à cause du mauva...
# 1   L'accès à la résidence n'est pas évidente en ...
# 2   L'accès est impraticable surtout en saison de...
# 3   La route n'est pas accessible | Le calme et l...
# 4   La TV ne fonctionne pas normalement. Le trans...

# %%
df_Toundalia = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Toundalia.csv", sep=";")#Toundalia

# %%
df_Toundalia.head()
# Out:
#    note                                             resume  \
# 0   7.0                    Paisible, propre et accueillant
# 1   6.0  Paisibe et accueillant, si ce n´est le bruit d...
# 2   8.0                                               Bien
# 3   8.0                 On s'y sent presque comme chez soi
# 4   7.9                             Bon séjour en général
#
#                                         commentaires
# 0   Le calme pour travailler et/ou se reposer y e...
# 1   Bruit des chiens de l´hôtel qui restent trop ...
# 2   La principale était verroullée dans la nuit, ...
# 3   J'ai aimé la propreté et la liberté du local....
# 4   La difficulté à retrouver le lieu pour la pre...

# %%
df_joliJardin = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\joli_jardin_en_ville.csv", sep=";")#joli_jardin_en_ville

# %%
df_joliJardin .head()
# Out:
#    note                                         resume  \
# 0   7.5                                  Très agréable
# 1   9.6  Apparemment idéal pour  un séjour tranquille
# 2   7.1                                         Bien
# 3  10.0                                       Parfait.
# 4  10.0                                  Exceptionnel
#
#                                         commentaires
# 0                     La disponibilité du personnel|
# 1   Les photos de famille à l'intérieur de l'appa...
# 2   Localisation très centrale et pres de tout ma...
# 3   Mon séjour était selon mes attentes. Le perso...
# 4   L emplacement l   Accueil.  Le confort  etc| ...

# %%
df_Hilton = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Hilton.csv", sep=";")#Hilton

# %%
df_Hilton.head()
# Out:
#    note            resume                                       commentaires
# 0   7.0            Bien     Le fait que la navette de l’hôtel ne soit pas...
# 1   9.0        Fabuleux                            Tout était correct| Tout|
# 2   7.0  Hôtel Acceptable   L'hôtel a vieillit, il faut absolument le rén...
# 3   8.0        Très bien    La moquette : pourquoi Hilton ne s’adapte pas...
# 4   9.0              Bien   Balcon sale meuble vieillot| La chambre est v...

# %%
df_ManoirPrinc = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Manoir_des_princesses.csv", sep=";")#Manoir_des_princesses

# %%
df_ManoirPrinc.head()
# Out:
#    note                                             resume  \
# 0   8.0                                         Très bien
# 1   8.0                               Séjour très agréable
# 2   8.0  Etablissement bien situé. Bon rapport qualité/...
# 3   7.1                                             Bien
# 4   9.2                                           Agréable
#
#                                         commentaires
# 0   A côté il y a une église réveillé qui dérange...
# 1                                  Ras| La propreté|
# 2   Le manque de climatiseur. La gérante affirme ...
# 3   La connexion Wi-Fi etait inexistante, 2000fcf...
# 4   L'accès à la restauration| Le calme,la sécuri...

# %%
df_luxxor = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\hotel luxxor.csv", sep=";")#hotel luxxor

# %%
df_luxxor.head()
# Out:
#    note                                             resume  \
# 0   8.0  Excellent séjour! J'y reviendrai volontiers dè...
# 1   8.0                           Le séjour était agréable
# 2   6.0                               Des efforts s'impose
# 3   7.0                                             Bien
# 4   8.0                                      Appréciation
#
#                                         commentaires
# 0   Le Wifi qui ne marche pas bien au 6ème étage....
# 1                                        Le confort|
# 2                    Le repas| La cuisine est nulle|
# 3   Agréable.. Revoyez juste les salles d'eaux......
# 4   Personnels très aimables,  Propreté assurée.....

# %%
df_Bouns = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Bouns hotel.csv", sep=";")#Bouns hotel

# %%
df_Bouns.head()
# Out:
#    note                resume  \
# 0   7.5                Bien
# 1   8.0      Excellent séjour
# 2   7.0                Bien
# 3   6.0  Bon Hotel à retester
# 4   8.0            Très bien
#
#                                         commentaires
# 0   Le personnel dédié aux prestations Spa est in...
# 1   Le personnel pas très professionnel  Le parki...
# 2   -Revoir le système electrique: problèmes d'ac...
# 3   Le fait que certaines zones communes ne soien...
# 4   Endroit calme avec piscine agréable. Le perso...

# %%
df_ApaprtMeub = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\meuble_ap.csv", sep=";")#appart_meubles

# %%
df_ApaprtMeub.head()
# Out:
#    note                                             resume  \
# 0   7.5  Pas pour homme d'affaires pressé ,mais idéal p...
# 1   8.8                                         Execelente
# 2   6.3                                          Agréable
# 3   7.1                                             Bien
# 4   7.1                                             Bien
#
#                                         commentaires
# 0   Assez loin du centre (moto +taxi nécessaires)...
# 1                                    Distance| Tout|
# 2   Manque de groupe électrogène, pauvre offre de...
# 3                                                NaN
# 4                                                NaN

# %%
df_mansel = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\mansel.csv", sep=";")#Mansel hotel

# %%
df_mansel.head()
# Out:
#    note                                             resume  \
# 0   7.9                           Agréable dans l'ensemble
# 1   5.8                                          Passable
# 2   6.3                                          Agréable
# 3   6.7  Hotel moyen en équipement mais avec très bonne...
# 4   7.1                                             Bien
#
#                                         commentaires
# 0   J'ai pas eu accès aux chaînes Canal sport qui...
# 1              Le manque d’ascenseur | La propreté |
# 2          Le personnel est inexpérimenté. | Le lit|
# 3   Refaire les travaux au niveau des douches| la...
# 4   Le personnel d'accueil n'était pas du tout co...

# %%
df_djeugaPal = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\djeuga_palace.csv", sep=";")#djeuga_palace

# %%
df_djeugaPal.head()
# Out:
#    note      resume                                       commentaires
# 0   7.0  Bon séjour   Les installations (climatisation) et le délai...
# 1   6.0   Agréable    Les chambres sont veillottes beaucoup de mois...
# 2   6.0   Agréable    *Le bruit du nightclub à côté *Le temps de re...
# 3   7.0    Passable   J'ai bu du movais whyski dans votre boîte| Le...
# 4   5.0   Passable    la vétusté des chambres et douche.| la nourri...

# %%
df_massaoPal = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\massao_palace.csv", sep=";")#massao_palace

# %%
df_massaoPal.head()
# Out:
#    note          resume                                       commentaires
# 0   6.0       Agréable    Qu'on essaie à chaque fois de me faire payer ...
# 1   8.0      Très bien    Les images de la télé et les chaînes associée...
# 2   7.0    C etait cool   Le lit| J ai aimé le standing mais le lit eta...
# 3  10.0   Exceptionnel                                     Excellent état|
# 4   1.0      Médiocre     Problème de communication, gestion inexistant...

# %%
df_montFebe = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\mont febe.csv", sep=";")#mont febe

# %%
df_montFebe.head()
# Out:
#    note                                             resume  \
# 0   5.0                                          Passable
# 1   7.0        Excellent! Je recommande et j'y reviendrai!
# 2   6.0                                           Agréable
# 3   6.7  Malgré que l'hôtel a pris de l'âge il est bien...
# 4   5.4                                            dommage
#
#                                         commentaires
# 0   La vétusté de la chambre. L'absence de petit ...
# 1   Le coin bar est peu emmenage, Des canapes et ...
# 2                       L'hôtel doit être renouvelé|
# 3   surtout pour le petit  déjeuné  rien avoir av...
# 4   chasse d'eau en panne une seule prise a la sa...

# %%
df_providence = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\providence.csv", sep=";")#residence_providence

# %%
df_providence.head()
# Out:
#    note          resume                                       commentaires
# 0   8.0      Très bien    Personnel très accueillant, avec beaucoup de ...
# 1   2.0      Médiocre     Publicité mensongère.| Le calme et la sécurit...
# 2   2.0      Médiocre     Il ya seulement une toilette et non deux comm...
# 3  10.0   Exceptionnel                                                 NaN
# 4   9.0      Fabuleux                                                  NaN

# %%
df_seas = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\seas.csv", sep=";")#7 seas wakanda

# %%
df_seas.head()
# Out:
#    note       resume                                    commentaires
# 0   6.0    Agréable                          La discrétion du lieu |
# 1   8.0   Très bien    Cool. Coin accessible et sécurisé.| Le décor|
# 2   6.0    Agréable                                              NaN
# 3   5.0    Passable                                              NaN

# %%
df_bastosap = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\part_b.csv", sep=";")#Bastos Appart's

# %%
df_bastosap.head()
# Out:
#    note                                             resume  \
# 0   8.0                                         Très bien
# 1   6.0                                          Agréable
# 2   7.0                                 Spacieux à visiter
# 3   8.8  Je recommande Bastos'appart à mon entourage. D...
# 4   5.8                                   Peut mieux faire
#
#                                         commentaires
# 0   Le comportement de Celui qui nous a accueilli...
# 1   L’entretien, la salubrité, le ménage sont à a...
# 2       Parking petit| Assez agréable, sécuritaire |
# 3   Déjà réglé avec la direction.| Le sentiment d...
# 4   la qualité approximative du ménage, l'absence...

# %%
df_noah = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\W_noah.csv", sep=";")#With Noah

# %%
df_noah.head()
# Out:
#    note        resume   commentaires
# 0   7.0        Bien              NaN
# 1   8.0    Très bien             NaN
# 2   9.0  Juste genial            NaN

# %%
df_Stsulpi = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Saint_sulpice.csv", sep=";")#Saint_sulpice

# %%
df_Stsulpi.head()
# Out:
#    note                                             resume  \
# 0   6.0  je suis satisfaite de mon sejour au point ou j...
# 1  10.0                                         Magnifique
# 2   5.0                                          Passable
# 3   5.0                                          Passable
# 4   8.0                                         Très bien
#
#                                         commentaires
# 0          rien| la maison est tres propre et calme|
# 1             J’ai tout aimé| Le personnel agréable|
# 2   Presque tout..mais surtout les voisins de l’a...
# 3   Il n'existe pas sur ce site, une précision de...
# 4                                                NaN

# %%
df_LeFibi = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Le_fibi.csv", sep=";")#Le_fibi

# %%
df_LeFibi.head()
# Out:
#    note                                             resume  \
# 0   4.0  Séjour pas très confortable, trop de bruits la...
# 1   3.8  j'ai apprecié l'acueil du personnel mais de gr...
# 2   5.0                                          Passable
# 3   3.0                                   Assez médiocre
# 4   5.0                                          Passable
#
#                                         commentaires
# 0   Pas de connexion wifi, chambres non insonoris...
# 1   les equipements usés, les draps ont viré du b...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_Hresi = pd.read_csv("C:\\Users\\lemec\\Desktop\\Hotels_scrapping\Hresi.csv", sep=";")#residence_H

# %%
df_Hresi.head()
# Out:
#    note                                     resume  \
# 0   8.0                                 Très bien
# 1   8.0  Confortable et gentillesse du personnelle
# 2   9.0                             Magnifique....
# 3   8.0                         c'était" perfect."
# 4   7.0                                     Bien
#
#                                         commentaires
# 0   Les coupures  d'électricité | Le personnel es...
# 1   Pas de wifi. | Emplacement et le calme et la ...
# 2   RAS| L'accueil, l'hygiène et le cadre de loge...
# 3   les chaines du cable n étais pas accessibles,...
# 4   pourrais mieux faire, problème d'évacuation d...

# %% [markdown]
# # Great Job
#
# ### Continue ....
